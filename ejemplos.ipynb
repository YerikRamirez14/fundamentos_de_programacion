# %% [markdown]
# <a href="https://colab.research.google.com/github/YerikRamirez14/fundamentos_de_programacion/blob/main/ejemplos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
base = input ("dame la base del triangulo")
altura = input ("dame la altura del triangulo")
area = (int(base)*int(altura))/2
print("el area del triangulo es", area)
# Out:
# dame la base del triangulo5
# dame la altura del triangulo5
# el area del triangulo es 12.5

# %%
z = 10
a = "Hola"
print(z * a)
# Out:
# HolaHolaHolaHolaHolaHolaHolaHolaHolaHola

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
    print("el numero", numero1, "es mayor que", numero2)
else:
    print("el numero", numero2, "es mayor que",numero1)
# Out:
# el numero 40 es mayor que 20
